# %% [markdown]
# # Linear regression  simpleexample

# %%
# domain analysis- from file we will get insights 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Advertising.csv')  # load data set

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head() # tv ,radio , newspapers are features and sales is target (label)
# indepedent variables are tv, radio ,newspaper and depedent varaibles is sales
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# tv ,radio , newspapers are features and sales is target

# %%
df.describe() # insights -obervations take some observations from dataset
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# - above  insights /observations are
# - advertising on tv on average costs more than radio or obeservations
# - sales happened  even though no money was spent on radio advertising
# - max amount spent on tv other than 2

# %%
df.info() # information of data or features 
# check missing value ,null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape() # ?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7544\1472378890.py in <module>
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
#  # Exploratory data analysis # EDA
#  - plotting insights from graph
#  - JUST DOING OBSERVATIOBNS FROM GRAPH

# %%
# step1: univariate analysis : one variable observation  
#shows  understands each attribute

# %%
sns.displot(x=df['TV'], data=df,kde=True) # DISPLOT  - represent data in histogram form. It is a univariant set of collected data, which means the data distribution of one variable will be shown against another variable. 
# In Python, we use the Seaborn library with Matplotlib for data visualization.

# %%
sns.displot(x=df['Radio'],data=df,kde=True) # kde for curve 
plt.show()

# %%
sns.displot(x=df['Newspaper'],data=df,kde=True) # kde for curve 
plt.show()

# %% [markdown]
# #### from above insights pepople spend much money on newspaper

# %%
# step2: Bivariate analysis # TWO FEATURE RELATIONSHIP SHOWS

# %%
# analyze tv and sales 
sns.relplot(x='TV',y='Sales',data=df) # relational plot

# %% [markdown]
# - more amount spent on tv advertisement leads more sales

# %%
sns.relplot(x='Radio',y='Sales',data=df) 
plt.show()

# %% [markdown]
# - radio advertisments sales not always growing nt showing trends

# %%
sns.relplot(x='Newspaper',y='Sales',data=df) 
plt.show()

# %% [markdown]
# -  no obvious trend noticeble between newpaper and sales

# %%
# comparing each an every column weith another column using multivariavate analysis

# %%
#  multivariavate analysis use pairplot # parplot ?

# %%
sns.pairplot(df) 
plt.show()

# %% [markdown]
#  # Data preprocessing and feature engineering

# %%
 #step 1: check for null value 
df.isnull().sum() # null is present or not ?
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
# step2: converting categorical data into nummerical  but we have all numerical data in df

# %%
# step3- checking for outliers 
sns.boxplot(x='TV',data=df)
plt.show()

# %% [markdown]
# - no outlier in tv

# %%
sns.boxplot(x='Radio',data=df)
plt.show()

# %% [markdown]
# - no outlier in radio

# %%
sns.boxplot(x='Newspaper',data=df)
plt.show()

# %% [markdown]
# - 2 outiars but not removing because not affecting sales

# %%
# step4-  scaling the data -  # use from  sklearn.preprocessing import StandardScalar

# %%
# step5 - transformations  # use log ,boxtox ,etc ?

# %%
 # step 6;- balancing the data # this is for classification problem 
# means unbalnce dataset is present over samplinfg and undersampling so use smote 
# using SMOTE  0s and 1s are amde equal

# %%
# this are above all steps if data is given

# %% [markdown]
# #  feature engg- i. feature selection - indepedent variables

# %%
df.head() # tv ,radio newpaper are features imp.
# we have to select which feature is imp you have selct that features and delete niot imp. variables
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
# step1: Dropping all columns with unwanted variables

# %%
# drop or remove unnamed 0 
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head() # unnamed column get remove
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
sns.heatmap((df.drop('Sales',axis=1)).corr()) # check the correlation between other elements using heatmap
plt.show()

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
df.drop('Sales',axis=1).corr() # we select 3 features only
# Out:
#                  TV     Radio  Newspaper
# TV         1.000000  0.054809   0.056648
# Radio      0.054809  1.000000   0.354104
# Newspaper  0.056648  0.354104   1.000000

# %% [markdown]
#  # Model Creation - imp .step

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
# step1: Indepedent and dependent variable creation

# %%
x= df[['TV','Radio','Newspaper']] # x contain all inputs 
y=df['Sales'] # y contain output i.e target

# %%
x # Indepedent features varaibles or features
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y # series  
# target
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
# 1. training and testing data

# %%
from sklearn.model_selection import train_test_split # split the data
# training data and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
x_train # training variables
# Out:
#         TV  Radio  Newspaper
# 72    26.8   33.0       19.3
# 18    69.2   20.5       18.3
# 175  276.9   48.9       41.8
# 77   120.5   28.5       14.2
# 6     57.5   32.8       23.5
# ..     ...    ...        ...
# 122  224.0    2.4       15.6
# 140   73.4   17.0       12.9
# 81   239.8    4.1       36.9
# 56     7.3   28.1       41.4
# 66    31.5   24.6        2.2
#
# [150 rows x 3 columns]

# %%
y_train
# Out:
# 72      8.8
# 18     11.3
# 175    27.0
# 77     14.2
# 6      11.8
#        ...
# 122    11.6
# 140    10.9
# 81     12.3
# 56      5.5
# 66      9.5
# Name: Sales, Length: 150, dtype: float64

# %%
x_test # testing varabiles take from dataset
# Out:
#         TV  Radio  Newspaper
# 174  222.4    3.4       13.1
# 28   248.8   27.1       22.9
# 145  140.3    1.9        9.0
# 180  156.6    2.6        8.3
# 57   136.2   19.2       16.6
# 69   216.8   43.9       27.2
# 151  121.0    8.4       48.7
# 139  184.9   43.9        1.7
# 96   197.6    3.5        5.9
# 31   112.9   17.4       38.6
# 101  296.4   36.3      100.9
# 125   87.2   11.8       25.9
# 152  197.6   23.3       14.2
# 176  248.4   30.2       20.3
# 166   17.9   37.6       21.6
# 182   56.2    5.7       29.7
# 86    76.3   27.5       16.0
# 17   281.4   39.6       55.8
# 35   290.7    4.1        8.5
# 5      8.7   48.9       75.0
# 37    74.7   49.4       45.7
# 169  284.3   10.6        6.4
# 91    28.6    1.5       33.0
# 136   25.6   39.0        9.3
# 78     5.4   29.9        9.4
# 47   239.9   41.5       18.5
# 76    27.5    1.6       20.7
# 154  187.8   21.1        9.5
# 59   210.7   29.5        9.3
# 149   44.7   25.8       20.6
# 124  229.5   32.3       74.2
# ...

# %%
y_test # target test
# Out:
# 174    11.5
# 28     18.9
# 145    10.3
# 180    10.5
# 57     13.2
# 69     22.3
# 151    11.6
# 139    20.7
# 96     11.7
# 31     11.9
# 101    23.8
# 125    10.6
# 152    16.6
# 176    20.2
# 166     8.0
# 182     8.7
# 86     12.0
# 17     24.4
# 35     12.8
# 5       7.2
# 37     14.7
# 169    15.0
# 91      7.3
# 136     9.5
# 78      5.3
# 47     23.2
# 76      6.9
# 154    15.6
# 59     18.4
# 149    10.1
# 124    19.7
# 177    11.7
# 184    17.6
# 49      9.7
# 113    15.9
# 82     11.3
# 73     11.0
# 7      13.2
# 83     13.6
# 2       9.3
# 107     8.7
# 93     22.2
# 119     6.6
# 25     12.0
# 156    15.3
# 148    10.9
# 129     9.7
# 191     9.9
# 45     14.9
# 88     12.9
# Name: Sales, dtype: float64

# %%
# step3 : creating the model 
from sklearn.linear_model import LinearRegression 
# actually use algorithm

# %%
# model for linear regression 
LR= LinearRegression()#object creation
# apply lr algo

# %%
LR
# Out:
# LinearRegression()

# %%
LR.fit(x_train,y_train) # trainig the model
# Out:
# LinearRegression()

# %%
                                                                                                                                                                                                                                                                                        y_pred=LR.predict(x_test) # getting predictions  # on testing data

# %%
y_test # actual
# Out:
# 151    11.6
# 164    11.9
# 162    14.9
# 86     12.0
# 52     22.6
# 59     18.4
# 121     7.0
# 37     14.7
# 44      8.5
# 177    11.7
# 183    26.2
# 165    11.9
# 80     11.8
# 193    19.6
# 10      8.6
# 155     3.2
# 62     15.7
# 32      9.6
# 129     9.7
# 60      8.1
# 180    10.5
# 69     22.3
# 145    10.3
# 61     24.2
# 97     15.5
# 20     18.0
# 171    14.5
# 28     18.9
# 109    19.8
# 122    11.6
# 101    23.8
# 116    12.2
# 58     23.8
# 199    13.4
# 128    24.7
# 78      5.3
# 103    14.7
# 191     9.9
# 125    10.6
# 43     12.9
# 33     17.4
# 64     18.0
# 184    17.6
# 154    15.6
# 190    10.8
# 46     10.6
# 194    17.3
# 70     18.3
# 56      5.5
# 106     7.2
# Name: Sales, dtype: float64

# %%
y_pred
# Out:
# array([13.64694701, 19.5494065 ,  9.59570936, 10.48931679, 12.82718384,
#        21.41712406,  9.78035498, 20.09790857, 12.56839473, 11.26837009,
#        23.12903204,  9.03894594, 16.48488754, 20.16674623, 11.04351907,
#         6.37035683, 11.73858654, 23.36085143, 16.95383209, 12.57440755,
#        15.8782862 , 17.97319567,  4.24140438, 11.74895001,  8.99760861,
#        22.048911  ,  4.28195609, 15.62099857, 18.35689413,  9.91878137,
#        19.40670262, 12.00025981, 18.57693176,  8.02260859, 16.51621765,
#        10.1556034 ,  9.7265242 , 12.20056742, 14.66591772, 12.39747266,
#         6.89907818, 21.24251319,  6.78355704, 15.49198648, 15.55193845,
#        12.56431177,  7.71063596,  8.41584059, 15.19024936, 11.55803156])

# %%
# check accuracy : 
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred) # use for classification
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7544\2731726535.py in <module>
# ----> 1 accuracy_score(y_test,y_pred) # use for classification
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#     102     # No metrics support "multiclass-multioutput" format
#     103     if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# ...

# %%
# model evaluation   # check performance mean .mse, mae,r2 score check the performance of our model

# %%
# in linear regression evalueates ,mean square error ,mean absolute error, r2 score

# %% [markdown]
# - R2 score -explains how much variablity in target can be explain in model

# %%
# dumbed model- for any input the output is mean(training data)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
r2_score=r2_score(y_test,y_pred)

# %%
r2_score  # check the accuracy or performace of linear regression
# Out:
# 0.8559627419825793

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 3.378595538959828

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 1.172605645600597

# %%
x_test.shape # gives no. of data points and columns
# Out:
# (50, 3)
